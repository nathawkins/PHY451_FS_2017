# %% [markdown]
# Analysis of Preliminary Trail Data Pulled from Cavendish Balance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import math as m
from scipy.signal import argrelextrema as argex
plt.style.use('ggplot')

# %%
data_dir = '../data/'
filename = '20171024_cavendish_driven_osc_2.txt'
data = np.loadtxt(data_dir+filename, delimiter='\t')

# %%
plt.plot(data[:,0], data[:,1])
plt.title("Cavendish Balance, {}".format(filename))
plt.ylabel("Anglular Positon (mrads)")
plt.xlabel("Time (s)");

# %%
np.max(data[:,0])
# Out:
# 3212.0
